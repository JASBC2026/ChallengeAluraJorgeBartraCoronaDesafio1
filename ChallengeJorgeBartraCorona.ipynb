# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
ingreso_tienda1 = tienda['Precio'].sum()
ingreso_tienda2 = tienda2['Precio'].sum()
ingreso_tienda3 = tienda3['Precio'].sum()
ingreso_tienda4 = tienda4['Precio'].sum()

# %%
# Sumando solo el precio de las ventas, sin considerar las cuotas
print(f'El valor total de ingresos de la tienda 1 es de:${ingreso_tienda1}')
print(f'El valor total de ingresos de la tienda 2 es de:${ingreso_tienda2}')
print(f'El valor total de ingresos de la tienda 3 es de:${ingreso_tienda3}')
print(f'El valor total de ingresos de la tienda 4 es de:${ingreso_tienda4}')

# Facturación total de todas las tiendas
facturacion_total = ingreso_tienda1 + ingreso_tienda2 + ingreso_tienda3 + ingreso_tienda4
print(f"\nFacturación total de todas las tiendas: ${facturacion_total:.2f}")
# Out:
# El valor total de ingresos de la tienda 1 es de:$1150880400.0
# El valor total de ingresos de la tienda 2 es de:$1116343500.0
# El valor total de ingresos de la tienda 3 es de:$1098019600.0
# El valor total de ingresos de la tienda 4 es de:$1038375700.0
#
# Facturación total de todas las tiendas: $4403619200.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Función para calcular y mostrar las ventas por categoría de una tienda
def ventas_por_categoria(tienda, numero):
    ventas = tienda.groupby('Categoría del Producto')['Precio'].sum()
    print(f"\nVentas por categoría en Tienda {numero}:")
    print(ventas)

# Mostrar resultados para cada tienda
ventas_por_categoria(tienda, 1)
ventas_por_categoria(tienda2, 2)
ventas_por_categoria(tienda3, 3)
ventas_por_categoria(tienda4, 4)
# Out:
# Ventas por categoría en Tienda 1:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64
#
# Ventas por categoría en Tienda 2:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64
#
# Ventas por categoría en Tienda 3:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def clasificacion_promedio(tienda, numero):
    promedio = tienda['Calificación'].mean()
    print(f"Clasificación promedio en Tienda {numero}: {promedio:.2f}")

# Mostrar resultados para cada tienda
clasificacion_promedio(tienda, 1)
clasificacion_promedio(tienda2, 2)
clasificacion_promedio(tienda3, 3)
clasificacion_promedio(tienda4, 4)
# Out:
# Clasificación promedio en Tienda 1: 3.98
# Clasificación promedio en Tienda 2: 4.04
# Clasificación promedio en Tienda 3: 4.05
# Clasificación promedio en Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
urls = [
"https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
"https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv",
"https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv",
"https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

]

df_total = pd.concat(
    [pd.read_csv(url).assign(Tienda=f"Tienda {i+1}") for i, url in enumerate(urls)],
    ignore_index=True
)

#  Preparación de Datos
df_total['Fecha de Compra'] = pd.to_datetime(df_total['Fecha de Compra'])

# Renombramos y tipamos si es necesario (asumiendo que la lectura ya lo hizo correctamente)
# Si 'Precio' y 'Cantidad de cuotas' son cargados correctamente desde el CSV,

df_total['Precio'] = df_total['Precio'].astype(float)

#  Cálculo de Ingresos y Ventas Agrupadas

ventas = df_total.groupby(['Tienda', 'Producto'])['Precio'].sum().reset_index(name='Ingresos_Totales')


def analizar_tienda(tienda_df, tienda_nombre):
    """Muestra el TOP 3 de productos que más y menos ingresos generaron para una tienda."""

    # Ordenar por ingresos totales
    ordenado = tienda_df.sort_values(by='Ingresos_Totales', ascending=False)

    # TOP MÁS VENDIDOS (Método .to_string() para formato de salida limpio)
    print(f"\n{tienda_nombre} - TOP 3 productos que MÁS dinero generaron:")
    print(ordenado.head(3).to_string(
        index=False, columns=['Producto', 'Ingresos_Totales'],
        formatters={'Ingresos_Totales': '${:,.2f}'.format}
    ))

    print(f"\n{tienda_nombre} - TOP 3 productos que MENOS dinero generaron:")
    # TOP MENOS VENDIDOS (Ordenamos de forma ascendente y tomamos los primeros 3)
    print(ordenado.tail(3).to_string(
        index=False, columns=['Producto', 'Ingresos_Totales'],
        formatters={'Ingresos_Totales': '${:,.2f}'.format}
    ))

#  Iterar y Analizar
for tienda_nombre in ventas['Tienda'].unique():
    # Filtramos UNA SOLA VEZ antes de llamar a la función
    data_tienda = ventas[ventas['Tienda'] == tienda_nombre]
    analizar_tienda(data_tienda, tienda_nombre)
# Out:
# Tienda 1 - TOP 3 productos que MÁS dinero generaron:
#      Producto Ingresos_Totales
# TV LED UHD 4K  $142,150,200.00
#  Refrigerador  $112,143,300.00
#     Iphone 15   $97,902,200.00
#
# Tienda 1 - TOP 3 productos que MENOS dinero generaron:
#           Producto Ingresos_Totales
#    Cubo mágico 8x8      $696,900.00
#     Dinosaurio Rex      $688,900.00
# Cuerda para saltar      $652,800.00
#
# Tienda 2 - TOP 3 productos que MÁS dinero generaron:
#      Producto Ingresos_Totales
#     Iphone 15  $113,225,800.00
# TV LED UHD 4K  $103,375,000.00
#  Refrigerador   $97,632,500.00
#
# Tienda 2 - TOP 3 productos que MENOS dinero generaron:
#           Producto Ingresos_Totales
# Cuerda para saltar      $856,900.00
#     Dinosaurio Rex      $770,300.00
#    Cubo mágico 8x8      $643,600.00
#
# Tienda 3 - TOP 3 productos que MÁS dinero generaron:
#      Producto Ingresos_Totales
#  Refrigerador   $99,889,700.00
# TV LED UHD 4K   $96,669,100.00
#     Iphone 15   $93,225,700.00
#
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
df_total['Costo de envío'] = df_total['Costo de envío'].astype(float)

envio_promedio = df_total.groupby('Tienda')['Costo de envío'].mean()

print("\nEnvío promedio por tienda:")
for tienda, promedio in envio_promedio.items():
    print(f"{tienda}: ${promedio:.2f}")
# Out:
# Envío promedio por tienda:
# Tienda 1: $26018.61
# Tienda 2: $25216.24
# Tienda 3: $24805.68
# Tienda 4: $23459.46

# %% [markdown]
# # Gráficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### **Gráfico de Ingresos totales de cada  tienda**

# %%
# Agrupamos los datos
ingresos_totales = df_total.groupby('Tienda')['Precio'].sum()
#El colo verde es para diferenciar la tienda con menor ingreso de las otras tiendas con mayores ingresos
colores = ['#1f77b4', '#1f77b4', '#1f77b4', 'green']

plt.figure(figsize=(8,5))
# Usamos el parámetro 'color' para aplicar la paleta
ingresos_totales.plot(kind='bar', color=colores)

plt.title('Ingresos Totales por Tienda (Tienda 4 = Menor Ingreso)', fontsize=15)
plt.ylabel('Total Ingresos (USD)')
plt.xlabel('Tienda')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0) # Mantenemos la etiqueta de la tienda horizontal
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Gráfico de promedio de ingreso por venta**

# %%
#  Promedio de ingreso por venta
ingreso_promedio = df_total.groupby('Tienda')['Precio'].mean()

plt.figure(figsize=(8,5))
ingreso_promedio.plot(kind='line', color=colores, style='o--')
plt.title('Ingreso Promedio por Venta por Tienda')
plt.ylabel('Ingreso Promedio (USD)')
plt.xlabel('Tienda')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Gráfico Ingreso acumulado por tienda**

# %%
# 1. Calcular ventas_mensuales
df_total['Fecha de Compra'] = pd.to_datetime(df_total['Fecha de Compra'], dayfirst=True)
ventas_mensuales = df_total.groupby(['Tienda', df_total['Fecha de Compra'].dt.to_period('M')])['Precio'].sum().reset_index()
ventas_mensuales['Fecha de Compra'] = ventas_mensuales['Fecha de Compra'].dt.to_timestamp()
ventas_mensuales = ventas_mensuales.set_index('Fecha de Compra')
ventas_mensuales = ventas_mensuales.rename(columns={'Precio': 'Ingresos_Mensuales'})

# 2. Definimos la paleta de colores para destacar la Tienda 4
color_map = {'Tienda 1': '#1f77b4', 'Tienda 2': '#ff7f0e', 'Tienda 3': '#2ca02c', 'Tienda 4': 'red'}

plt.figure(figsize=(12, 6))

# Corrected to use 'Tienda' column, as defined in ventas_mensuales
for tienda in ventas_mensuales['Tienda'].unique():
    data_tienda = ventas_mensuales[ventas_mensuales['Tienda'] == tienda].copy()
    data_tienda['Ingreso_Acumulado'] = data_tienda['Ingresos_Mensuales'].cumsum()

    # Graficamos, usando el color específico para la tienda
    sns.lineplot(data=data_tienda, x=data_tienda.index, y='Ingreso_Acumulado',
                 label=tienda, marker='', color=color_map[tienda])

plt.title('Ingreso Acumulado Total por Tienda - Destacando Tienda 4', fontsize=15)
plt.ylabel('Ingreso Total Acumulado (USD)')
plt.xlabel('Fecha')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend(title='Tienda')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **INFORME FINAL**

# %% [markdown]
# ####  El presente Informe tiene como objetivo analizar el desempeño de las 4 tiendas con el fin de determinar a cuàl debería vender el Sr. Jua. El objetivo se logrará , evaluando diferentes factores clave ,como los ingresos totales, el ingreso promedio por venta, el comportamiento de ventas, la satisfacción de los clientes y los costos de envío, apoyándose en los gráficos y análisis realizados.

# %% [markdown]
# #### A partir del análisis de ingresos, se observa que no todas las tiendas presentan el mismo nivel de facturación. la 4ta tienda , es la que menos ingresos totales tiene , lo que indica una menor volumen de veltas y peor performace comercial general frente al resto.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ####  La Tienda 1 genera más ingreso por cada venta, mientras que la Tienda 4 es la que menos genera en promedio, mostrando una menor rentabilidad por operación.
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
# #### El gráfico "Ingreso acumulado Total por tienda " muestra la evolución del ingreso total acumulado a lo largo del tiempo para cada tienda. Todas las tiendas presentan una tendencia creciente, lo que indica que generan ingresos de forma constante. Sin embargo, se observa que la Tienda 1 mantiene el mayor ingreso acumulado durante todo el período, posicionándose como la más rentable en términos globales.
#
# #### La Tienda 4, aunque crece de manera sostenida, se mantiene por debajo del resto, lo que evidencia un menor aporte al ingreso total acumulado. Esto sugiere que, a pesar de vender de forma continua, su volumen de ingresos es inferior en comparación con las otras tiendas.

# %% [markdown]
# #### La tineda recomendada es la primera porque se destaca por su mejor desempeño global, con mayores ingresos acumulados y un ingreso promedio por venta superior, lo que indica mayor rentabilidad. Además, presenta productos de alta rotación, mejores calificaciones de los clientes y costos de envío más competitivos.
#
# #### En comparación, las demás tiendas muestran menores ingresos o rentabilidad, lo que las vuelve menos competitivas.

# %% [markdown]
# #### podemos concluir que la primera tienda es la mejor opción para que el Sr. Juan realice la venta.  Esta tienda se destaca por presentar mayores ingresos acumulados, un ingreso promedio por venta más alto, productos de buena rotación y mejores calificaciones de los clientes, además de costos de envío competitivos.
#
# #### Si bien las demás tiendas muestran crecimiento y algunos puntos fuertes, no alcanzan el mismo nivel de rentabilidad y desempeño global, por lo que la Tienda 1 resulta la alternativa más conveniente.

# %% [markdown]
# # **¡Extra! Análisis del desempeño geográfico**

# %%
import folium
from folium.plugins import HeatMap
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### **Mapa de Calor Interactivo (Folium)**

# %%
# 1. Crear el mapa base centrado en Colombia
mapa_colombia = folium.Map(location=[4.5709, -74.2973], zoom_start=6, tiles='CartoDB positron')

# 2. Preparar los datos: Latitud, Longitud y el Precio (como peso del calor)
# Eliminamos nulos por si acaso
df_geo = df_total.dropna(subset=['lat', 'lon', 'Precio'])
data_heat = df_geo[['lat', 'lon', 'Precio']].values.tolist()

# 3. Añadir capa de calor
HeatMap(data_heat, radius=20, blur=15).add_to(mapa_colombia)

# Mostrar el mapa
mapa_colombia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# #### el mapa indica un punto rojo , lo cual indica Las ventas están masivamente concentradas en Bogotá y la región. Ciudades como Medellín, Cali y la zona costera (Cartagena/Barranquilla) tienen presencia, pero con un volumen de transacciones mucho menor.

# %% [markdown]
# #### **Gráfico de Dispersión: Ventas vs. Calificación**

# %%
plt.figure(figsize=(10, 6))

# El tamaño del punto será el Precio y el color la Calificación
sns.scatterplot(data=df_geo, x='lon', y='lat',
                hue='Calificación',
                size='Precio',
                sizes=(50, 500),
                palette='RdYlGn', # Rojo (bajo) a Verde (alto)
                alpha=0.7)

plt.title('Distribución Geográfica: Tamaño por Precio y Color por Calificación')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.show()

# %% [markdown]
# #### Dominamos en Bogotá con eficiencia, pero el rendimiento cae en las regiones (Medellín, Cartagena, Cali) debido a costos de envío más altos y una satisfacción al cliente inconsistente. Debemos mejorar la logística regional para igualar el éxito de la capital
